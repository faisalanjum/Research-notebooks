# %%
import pandas as pd  
import numpy as np
import datetime 
import dotenv
from os import listdir
from os.path import isfile, join
from datetime import datetime

from CommitmentsOfTraders.backend.db.models import *
from FEA.backend.db.models import * 
from WesternWoodPDFs.westernpdfabstractor.backend.db.models import *

# %% [markdown]
# # FEA

# %% [markdown]
# #### All FEA Series

# %% [markdown]
# # ISSUE with AGGREGATING only picks up TILL April 2022

# %%
# %load_ext dotenv 
# %dotenv C:\source\2x4_data\app\data\FEA\.env
from FEA.backend.db.models import * 
import FEA.backend.controllers.DataRetreivalControllerFEA as FEA_DATA

obj_FEA=FEA_DATA.DataRetreivalControllerFEA()

model_mapper_list=[
    ProductcensusbureaumacroeconomyandenduseSeriesList,
    Identifiers,
    ProductendusequarterlyforecastSeriesList,
    ProductcensusbureaumacroeconomyandenduseSeriesList,
    ProductcensusbureaumacroeconomyandenduseSeriesList,
    ProductfederalreserveSeriesList,
    ProductlumberquarterlyforecastSeriesList,
    ProductmacroeconomyquarterlyforecastSeriesList,
    ProductmonthlylumberadvisorSeriesList,
    ProductmonthlymacroeconomicadvisorSeriesList,
    ProductstatcanmacroeconomyandenduseSeriesList,
    ProductstatcansawmillsSeriesList]

fea_df = pd.DataFrame()
for mapper in model_mapper_list:
    try:
        data=obj_FEA.query_data(mapper=mapper)
        df=pd.DataFrame(data)
        print(mapper,df.frequency.unique())
        df = df.pivot_table(index=['date'],columns=['description'],values=['value']).sort_index(ascending=False)
        fea_df = pd.concat([fea_df, df], axis=1).fillna(method='ffill')
    except:
        print(mapper)
        pass

# fea_df = fea_df.fillna(method='bfill')
fea_df
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv
# postgresql://fanjum:3cUDV4jctsfF0pYcxoMQ@pg-prod-master.data-191214.com:5432/2x4
# Connection Established!
# <class 'FEA.backend.db.models.ProductcensusbureaumacroeconomyandenduseSeriesList'> ['m']
# <class 'FEA.backend.db.models.Identifiers'>
# <class 'FEA.backend.db.models.ProductendusequarterlyforecastSeriesList'> ['q']
# <class 'FEA.backend.db.models.ProductcensusbureaumacroeconomyandenduseSeriesList'> ['m']
# <class 'FEA.backend.db.models.ProductcensusbureaumacroeconomyandenduseSeriesList'> ['m']
# <class 'FEA.backend.db.models.ProductfederalreserveSeriesList'> ['m']
# <class 'FEA.backend.db.models.ProductlumberquarterlyforecastSeriesList'> ['a' 'q']
# <class 'FEA.backend.db.models.ProductmacroeconomyquarterlyforecastSeriesList'> ['q']
# <class 'FEA.backend.db.models.ProductmonthlylumberadvisorSeriesList'> ['m' 'q']
# ...

# %%
data=obj_FEA.query_data(mapper=ProductmonthlylumberadvisorSeriesList)
df=pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['name', 'description', 'frequency', 'source', 'created_at',
#        'updated_at', 'date', 'period', 'value', 'display', 'label',
#        'relationship_info', 'id', 'type', 'download_link'],
#       dtype='object')

# %%
# updated_at
df = df[df.frequency == 'm']
df1 = df.pivot_table(index=['date'],columns=['description'],values=['value']).sort_index(ascending=False)
df1
# Out:
#                                                                    value  \
# description Exchange Rate, United States Dollar per Canadian Dollar, NSA
# date
# 2026-12-01                                            0.818333
# 2026-11-01                                            0.820000
# 2026-10-01                                            0.821667
# 2026-09-01                                            0.823333
# 2026-08-01                                            0.825000
# ...                                                        ...
# 1971-05-01                                            0.991375
# 1971-04-01                                            0.992359
# 1971-03-01                                            0.993641
# 1971-02-01                                            0.992556
# 1971-01-01                                            0.988338
#
#                                                                            \
# ...

# %%
df1[50:]
# Out:
#                                                                    value  \
# description Exchange Rate, United States Dollar per Canadian Dollar, NSA
# date
# 2022-10-01                                            0.814815
# 2022-09-01                                            0.810185
# 2022-08-01                                            0.809630
# 2022-07-01                                            0.810185
# 2022-06-01                                            0.817834
# ...                                                        ...
# 1971-05-01                                            0.991375
# 1971-04-01                                            0.992359
# 1971-03-01                                            0.993641
# 1971-02-01                                            0.992556
# 1971-01-01                                            0.988338
#
#                                                                            \
# ...

# %%
from datetime import datetime

mapper =  ProductmonthlylumberadvisorSeriesList
lumberadvisor=obj_FEA.query_data(mapper=mapper)
lumberadvisor=pd.DataFrame(lumberadvisor)

# These 2 have to be put Manually each month once the report is out - Remember to pass this as an argument to the BIG AGGREGATE function
historical_month_end = '2022-04-01' # Open excel at below link and the last NON highlighted row is actuals

# Updated_on = '2022-05-27' # Found at https://getfea.com/publication/lumber-service/monthly-lumber-advisor
# Updated_on = datetime.strptime(Updated_on, '%Y-%m-%d').date()

# Once the database is getting updated we can use the following line - no need to update manually (remove above 2 lines)
Updated_on = datetime.strptime(lumberadvisor['updated_at'][0], "%Y-%m-%dT%H:%M:%S+00:00").date()
historical_month_end = datetime.strptime(historical_month_end, '%Y-%m-%d').date()
diff_days = (Updated_on - historical_month_end).total_seconds() / 60 / 60 / 24 

lumberadvisor = lumberadvisor.pivot_table(index=['date'],columns=['description'],values=['value']).sort_index(ascending=False)
lumberadvisor.index = pd.DatetimeIndex(lumberadvisor.index)
fea_balance_xl_link = 'F:/Traders/2x4/2x4 v2/Data/Fundamentals/Forest Economic Advisors/Lumber_Balance_FEA.xlsx'
fea_balance_xl = pd.read_excel(fea_balance_xl_link, sheet_name='Index')
fea_balance_col_list = fea_balance_xl['Description'].replace('\n', '').tolist()

lumberadvisor = lumberadvisor.loc[historical_month_end:,('value',fea_balance_col_list)]
lumberadvisor.index = lumberadvisor.index + pd.DateOffset(days=diff_days) # Manually entering 1 date (historical_month_end/last actual month reported) & then subtracting it from updated on (same as updated_at in db I think) and the diff is then added to the index

lumberadvisor.columns.set_levels(['Lumber_Advisor_' + str(x) for x in lumberadvisor.columns.levels[0]],level=0,inplace=True)

# lumberadvisor = lumberadvisor.reindex(daily_dataframe_main.index).fillna(method='bfill')
# daily_dataframe_main = pd.concat([daily_dataframe_main, lumberadvisor], axis=1)
# daily_dataframe_main.head(2).append(daily_dataframe_main.tail(2))
# Out:
# C:\Users\Fanjum_cwp\AppData\Local\Temp\2\ipykernel_9268\466712134.py:24: FutureWarning: The behavior of indexing on a MultiIndex with a nested sequence of labels is deprecated and will change in a future version. `series.loc[label, sequence]` will raise if any members of 'sequence' or not present in the index's second level. To retain the old behavior, use `series.index.isin(sequence, level=1)`
#   lumberadvisor = lumberadvisor.loc[historical_month_end:,('value',fea_balance_col_list)]
# C:\Users\Fanjum_cwp\AppData\Local\Temp\2\ipykernel_9268\466712134.py:27: FutureWarning: inplace is deprecated and will be removed in a future version.
#   lumberadvisor.columns.set_levels(['Lumber_Advisor_' + str(x) for x in lumberadvisor.columns.levels[0]],level=0,inplace=True)

# %%
lumberadvisor
# Out:
#                                            Lumber_Advisor_value  \
# description Softwood Lumber Apparent Consumption, North America
# date
# 2022-05-05                                            5.598671
# 2022-04-04                                            4.678540
# 2022-03-07                                            4.480420
# 2022-02-04                                            4.570250
# 2022-01-04                                            4.575570
# ...                                                        ...
# 1971-06-04                                                 NaN
# 1971-05-05                                                 NaN
# 1971-04-04                                                 NaN
# 1971-03-07                                                 NaN
# 1971-02-04                                                 NaN
#
#                                                         \
# description Softwood Lumber Consumption, North America
# date
# ...

# %%
# filter_list_dict['United States']

filter_list = ['North America','United States','Canada','Western SPF, 2x4 2&Btr.']
filter_list_dict = dict((el,0) for el in filter_list)



for f in filter_list:
    filter_list_dict[f] = lumberadvisor.filter(regex=f)

# %% [markdown]
# # Constructing Balance Sheet Items from Lumber Monthly Advisor

# %% [markdown]
# ## Lumber Advisor Monthly Series - Selected to Create a Balance

# %%
CUTOFF_DATE_END = '2023-12-01'
CUTOFF_DATE_START = '1990-01-01'
mapper =  ProductmonthlylumberadvisorSeriesList
lumberadvisor=obj_FEA.query_data(mapper=mapper)
lumberadvisor=pd.DataFrame(lumberadvisor)
lumberadvisor = lumberadvisor.pivot_table(index=['date'],columns=['description'],values=['value']).sort_index(ascending=False)
fea_balance_xl_link = 'F:/Traders/2x4/2x4 v2/Data/Fundamentals/Forest Economic Advisors/Lumber_Balance_FEA.xlsx'
fea_balance_xl = pd.read_excel(fea_balance_xl_link, sheet_name='Index')
fea_balance_col_list = fea_balance_xl['Description'].replace('\n', '').tolist()
# lumberadvisor = lumberadvisor.loc[CUTOFF_DATE_END:CUTOFF_DATE_START,('value',fea_balance_col_list)]
lumberadvisor_nam = lumberadvisor.filter(regex='North America')
lumberadvisor_us = lumberadvisor.filter(regex='United States')
lumberadvisor_can = lumberadvisor.filter(regex='Canada')
lumberadvisor_cash_price = lumberadvisor.filter(regex='Western SPF, 2x4 2&Btr.')
# lumberadvisor_nam.dropna(inplace=True)
# lumberadvisor_us.dropna(inplace=True)
# lumberadvisor_can.dropna(inplace=True)
# lumberadvisor_cash_price.dropna(inplace=True)

# %%
lumberadvisor_can

# %%
lumberadvisor_us

# %% [markdown]
# # Dealer Stocks by Cons Ratio

# %%
import matplotlib.pyplot as plt
lumberadvisor_nam_dealer_stocks = lumberadvisor_nam.filter(regex='Softwood Lumber Dealer Stocks/Consumption Ratio, North America').sort_index(ascending=True)
# flatten multi-index
lumberadvisor_nam_dealer_stocks.columns = ['%s%s' % (a, '|%s' % b if b else '') for a, b in lumberadvisor_nam_dealer_stocks.columns]
ax = lumberadvisor_nam_dealer_stocks.plot(color='blue', linewidth=2, figsize=(16,8));
lumberadvisor_nam_dealer_stocks.loc[lumberadvisor_nam_dealer_stocks.index < '2022-04-01'].plot(ax=ax, color='red', linewidth=2);

ax2 = ax.twinx() 

forecast_idx = lumberadvisor_nam_dealer_stocks.index.to_list().index('2022-04-01') - lumberadvisor_nam_dealer_stocks.index.to_list().index('2022-12-01') - 1
ax2.plot(lumberadvisor_cash_price[:forecast_idx], color = 'green', linewidth=2);

ax2.legend(['Cash Price'], loc='upper left');
plt.axvspan(lumberadvisor_nam_dealer_stocks.index.to_list().index('2022-04-01')-1, lumberadvisor_nam_dealer_stocks.index.to_list().index('2022-12-01'), color='grey', alpha=0.2);
ax.legend(['Dealer Inventory/Mill Consumption'], loc='upper right');

# %% [markdown]
# # Mills Stocks by Cons

# %%
nam_mill_by_cons = pd.concat([lumberadvisor_nam.filter(regex='Softwood Lumber Mill Inventory, North America'),lumberadvisor_nam.filter(regex='Softwood Lumber Consumption, North America')], axis=1)
nam_mill_by_cons.columns = ['Mill Inventory','Mill Consumption']
nam_mill_by_cons = nam_mill_by_cons['Mill Inventory']/nam_mill_by_cons['Mill Consumption']
nam_mill_by_cons.sort_index(ascending=True, inplace = True)
ax = nam_mill_by_cons.plot(color='blue', linewidth=2, figsize=(16,8));
nam_mill_by_cons.loc[nam_mill_by_cons.index < '2022-04-01'].plot(ax=ax, color='red', linewidth=2);
ax2 = ax.twinx() 
forecast_idx = nam_mill_by_cons.index.to_list().index('2022-04-01') - nam_mill_by_cons.index.to_list().index('2022-12-01') - 1
ax2.plot(lumberadvisor_cash_price[:forecast_idx], color = 'green', linewidth=2);
ax2.legend(['Cash Price'], loc='upper left');
plt.axvspan(nam_mill_by_cons.index.to_list().index('2022-04-01')-1, nam_mill_by_cons.index.to_list().index('2022-12-01'), color='grey', alpha=0.2);
ax.legend(['Mill Inventory/Mill Consumption'], loc='upper right');

# %% [markdown]
# # US Related Ratios

# %%
# lumberadvisor_us.columns.get_level_values(1)

# %%
us_cols_to_keep = ['Softwood Lumber Unfilled Orders/Stocks Ratio, United States','Softwood Lumber New Orders/Production Ratio, United States','Softwood Lumber Dealer Stocks/Consumption Ratio, United States','Softwood Lumber Demand/Capacity Ratio, United States']
lumberadvisor_us = lumberadvisor_us.loc[:,('value',us_cols_to_keep)]

# flatten multi-index
lumberadvisor_us.columns = ['%s%s' % (a, '|%s' % b if b else '') for a, b in lumberadvisor_us.columns]

# %%
lumberadvisor_us = lumberadvisor_us.sort_index(ascending=True)
for i in range(len(lumberadvisor_us.columns)):
    ax = lumberadvisor_us.iloc[:,i:i+1].plot(color='blue', linewidth=2, figsize=(16,8));
    lumberadvisor_us.iloc[:,i:i+1].loc[lumberadvisor_us.iloc[:,i:i+1].index < '2022-04-01'].plot(ax=ax, color='red', linewidth=2);  
    ax.legend([lumberadvisor_us.columns[i]], loc='upper left');

    ax2 = ax.twinx() 
    forecast_idx = lumberadvisor_us.index.to_list().index('2022-04-01') - lumberadvisor_us.index.to_list().index('2022-12-01') - 1
    ax2.plot(lumberadvisor_cash_price[:forecast_idx], color = 'green', linewidth=2);
    ax2.legend(['Cash Price'], loc='upper right');
    plt.axvspan(lumberadvisor_us.index.to_list().index('2022-04-01')-1, lumberadvisor_us.index.to_list().index('2022-12-01'), color='grey', alpha=0.2);
    plt.title(lumberadvisor_us.columns[i]);
    plt.show()

# %% [markdown]
# # Canada Related Ratios

# %%
lumberadvisor_can.head()

# %%
# temporarily saving prices in xlsx - since changing from one env to another deletes the variables
lumberadvisor_cash_price.to_excel('lumberadvisor_cash_price.xlsx')

# %% [markdown]
# # WWPA - Barometer

# %%
import matplotlib.pyplot as plt
import pandas as pd
# lumberadvisor_cash_price = pd.read_excel('lumberadvisor_cash_price.xlsx',skiprows=1)
# lumberadvisor_cash_price = lumberadvisor_cash_price.iloc[1:]
# lumberadvisor_cash_price.index = pd.to_datetime(lumberadvisor_cash_price.description)
# lumberadvisor_cash_price.drop(columns=['description'], inplace=True)
# lumberadvisor_cash_price.columns = ['Cash Price']
# lumberadvisor_cash_price.head()

# %%
# %reload_ext dotenv
# %dotenv C:\source\2x4_data\app\data\WesternWoodPDFs\westernpdfabstractor\backend\db\.env

# %%
from WesternWoodPDFs.westernpdfabstractor.Controller.DataRetreivalControllerWWPA import DataRetreivalControllerWWPA as WPDFDATA
wwpa_obj=WPDFDATA()

# %%
from WesternWoodPDFs.westernpdfabstractor.backend.db.models import *
# wwpa_obj.query_data(ProductionUS)

# %%
List_of_models = [ProductionUS,ShipmentUS,InventoryUS,OrdersUS,PPPC,UnfilledOrdersUS,ProductionCanada,ShipmentCanada,
                 InventoryCanada,LumberExportCanada,LogExportUS,LogImportsUS,ConsumptionLumberUs,LumberExportUS,
                 LumberImportsUS,ConsumptionLumberCanada,NorthAmericanProduction,NorthAmericanShipment,
                 NorthAmericanOrder,NorthAmericanUnfiledOrder,NorthAmericanInventory,OrdersWestern,PPPCWestern,
                 ProductionWestern,BarometerWestern,BarometerCoast,BarometerInland,BarometerFinishedInventories,
                 UnfilledOrderWestern,ShipmentWestern,InventoryWestern,ShipmentCoastal,ShipmentInland,AveragePriceCoastal,
                 AveragePriceIsland,AveragePriceCostalDoglas,AveragePriceCostalHamfir,AveragePriceIslandDouglas,
                 AveragePricePonderasoPine,AveragePriceWhiteWoods]

# %%
# Thes 2 functions required to extract the name of the report from the update table
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

def get_report_name(link):
    link_start = find_nth(link, "\\",8)
    link_end = find_nth(link, "\\",9)
    link_start +=1
    name = link[link_start:link_end]
    return name

# From table name (refer to models column in update dataframe above), get class model name which will be used to fetch information from the database
# from WesternWoodPDFs.westernpdfabstractor.backend.db.models import Base
def get_class_by_tablename(table_fullname):
  Base.TBLNAME_TO_CLASS = {}
  for mapper in Base.registry.mappers:
      cls = mapper.class_
      classname = cls.__name__
      if not classname.startswith('_'):
          tblname = cls.__tablename__
          Base.TBLNAME_TO_CLASS[tblname] = cls
  return Base.TBLNAME_TO_CLASS[table_fullname]

# %%
# %load_ext dotenv

# %%
wwpa_obj.query_data(OrdersWestern)

# %%
update_df  = pd.DataFrame(columns=['model','last_updated','Columns','report_name'])

# to_delete_list = []

List_of_error_models=[]
List_of_empty_models=[]

for model in List_of_models:
    
    try:
        data=wwpa_obj.query_data(model)
        model_data = pd.DataFrame(data)
        max_date = model_data['Timestamp'].max().strftime('%Y-%m-%d')
        columns = model.__table__.columns.keys()
        # .remove('Timestamp') Remove Timestamp from columns list
        model_name = model.__tablename__
        # to_delete_list.append(model_data['File'][0])
        report_name = get_report_name(model_data['File'][0])
        row_data = pd.DataFrame([[model_name,max_date,columns, report_name]],columns=['model','last_updated','Columns','report_name'])
        update_df = pd.concat([update_df, row_data], axis=0)
    except Exception as e:
        print(e)
        List_of_error_models.append(model.__tablename__)
        print("error in model {}".format(model.__tablename__))

# %%
Barometer_list = list(update_df[update_df['report_name'] == 'Barometer']['model'].values)
Barometer_list

# %%
# BarometerFinishedInventories - Note this is Monthly so forward filling it


barometer_data_dict = {}
Barometer_list = list(update_df[update_df['report_name'] == 'Barometer']['model'].values)

df = pd.DataFrame()

for name in Barometer_list:
    model = get_class_by_tablename(name)
    data=wwpa_obj.query_data(model)
    model_data = pd.DataFrame(data)
    model_data.sort_values(by=['Timestamp'],ascending=False,inplace=True)
    model_data.index = model_data['Timestamp']
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.drop(['Timestamp','Month','Day','File','Year'],axis=1,inplace=True)
    barometer_data_dict[model.__tablename__] = model_data

    cols = pd.MultiIndex.from_product([[model.__tablename__], (barometer_data_dict[model.__tablename__].columns)])
    barometer_data_dict[model.__tablename__].columns = cols
    barometer_data_dict[model.__tablename__] = barometer_data_dict[model.__tablename__][~barometer_data_dict[model.__tablename__].index.duplicated(keep='first')]
    df = pd.concat([df, barometer_data_dict[model.__tablename__]], axis=1).fillna(method='ffill').reindex(barometer_data_dict['barometer_western'].index)

df.head(7).append(df.tail(7))

# %%
barometer_western = df.loc[:,('barometer_western',)]
barometer_western

# %%
barometer_western['Inventories/New Orders'] = barometer_western['Inventories']/barometer_western['Orders']
barometer_western['Inventories/Unfilled Orders'] = barometer_western['Inventories']/barometer_western['Unfilled']
barometer_western['Total Orders'] = barometer_western['Orders'] + barometer_western['Unfilled']
barometer_western['Inventories/Total Orders'] = barometer_western['Inventories']/barometer_western['Total Orders']

barometer_western

# %%
barometer_western = barometer_western.drop(['Production','Orders','Unfilled','Shipments'],axis=1)
barometer_western

# %%
barometer_western = barometer_western.loc['2020-01-01':]

# %%
import matplotlib.pyplot as plt

for i in range(len(barometer_western.columns)):
    ax = barometer_western.iloc[:,i:i+1].plot(color='blue', linewidth=2, figsize=(16,8));
    ax.legend([barometer_western.columns[i]], loc='upper left');
    
    ax2 = ax.twinx() 
    # ax2.plot(lumberadvisor_cash_price['Cash Price'], color = 'green', linewidth=2);
    ax2.legend(['Cash Price'], loc='upper right');
    plt.title(barometer_western.columns[i]);
    plt.show()

# %%
data=cot_obj.query_data(DisaggregatedFuturesOptions)
model_data = pd.DataFrame(data)
# model_data = model_data[model_data.Report_Type == report_type]
model_data.index = model_data.Date
model_data.index = pd.DatetimeIndex(model_data.index)
model_data.drop(['Date','Report_Type'],axis=1,inplace=True)

model_data

# %%
# %reload_ext dotenv
# %dotenv  C:\source\2x4_data\app\data\CommitmentsOfTraders\backend\db\.env
from CommitmentsOfTraders.backend.controllers.DataRetreivalControllerCOT import DataRetreivalControllerCOT
from CommitmentsOfTraders.backend.db.models import *
cot_obj=DataRetreivalControllerCOT()


def cot_old_new(dis_or_leg,fut_or_futopt):
    
    report_type =  str(dis_or_leg + '_' + fut_or_futopt)

    if dis_or_leg == 'disaggregated':
        model_name =  DisaggregatedFuturesOptions
        columns_to_keep =['Date','Open_Interest_All','Prod_Merc_Positions_Long_All','Prod_Merc_Positions_Short_All','M_Money_Positions_Long_All','M_Money_Positions_Short_All','M_Money_Positions_Spread_All','Tot_Rept_Positions_Long_All','Tot_Rept_Positions_Short_All','Change_in_Open_Interest_All','Change_in_Prod_Merc_Long_All','Change_in_Prod_Merc_Short_All','Change_in_M_Money_Long_All','Change_in_M_Money_Short_All','Pct_of_Open_Interest_All','Pct_of_OI_Prod_Merc_Long_All','Pct_of_OI_Prod_Merc_Short_All','Pct_of_OI_M_Money_Long_All','Pct_of_OI_M_Money_Short_All','Pct_of_OI_M_Money_Spread_All']
        data=cot_obj.query_data(model_name)
        model_data = pd.DataFrame(data)
        model_data = model_data[model_data.Report_Type == report_type]

        model_data =model_data[columns_to_keep]
        model_data['M_Money_Positions_Long_All'] = model_data['M_Money_Positions_Long_All'].astype(int)
        model_data['M_Money_Positions_Short_All'] = model_data['M_Money_Positions_Short_All'].astype(int)
        model_data['Net_Spec_Length'] = model_data['M_Money_Positions_Long_All'] - model_data['M_Money_Positions_Short_All']
        model_data['Pct_of_OI_MM_NSL'] = model_data['Pct_of_OI_M_Money_Long_All'] - model_data['Pct_of_OI_M_Money_Short_All']

    elif dis_or_leg == 'legacy':
        model_name =  Legacy
        data=cot_obj.query_data(model_name)
        model_data = pd.DataFrame(data)
        model_data = model_data[model_data.Report_Type == report_type]
        model_data.drop(['Report_Type','Market_Code','Market_and_Exchange_Names','CFTC_Contract_Market_Code','CFTC_Market_Code_in_Initials','CFTC_Region_Code','CFTC_Commodity_Code','Contract_Units','CFTC_Contract_Market_Code_Quotes','CFTC_Market_Code_in_Initials_Quotes','CFTC_Commodity_Code_Quotes'],axis=1,inplace=True)

    else:
        raise ValueError('disaggregated or legacy')

    model_data.index = model_data.Date
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.drop(['Date'],axis=1,inplace=True)
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.sort_index(ascending=False,inplace=True)

    return model_data

# For Dissaggregated Report
COT = cot_old_new('disaggregated','futopt')
cols = pd.MultiIndex.from_product([['CFTC_disaggregated'], (COT.columns)])
COT = pd.DataFrame(data=COT.values, index=COT.index, columns=cols)
# The data released Friday at 3:30 pm est, for previous Tuesday (close). So since it doesn't impact Friday close, we move to to next Monday by adding 6 days
COT.index = COT.index + pd.DateOffset(days=6)
COT.sort_index(ascending = False, inplace=True)

# FOR Legacy Report
COT_legacy = cot_old_new('legacy','futopt')
cols = pd.MultiIndex.from_product([['CFTC_legacy'], (COT_legacy.columns)])
COT_legacy = pd.DataFrame(data=COT_legacy.values, index=COT_legacy.index, columns=cols)
# The data released Friday at 3:30 pm est, for previous Tuesday (close). So since it doesn't impact Friday close, we move to to next Monday by adding 6 days
COT_legacy.index = COT_legacy.index + pd.DateOffset(days=6)
COT_legacy.sort_index(ascending = False, inplace=True)
# Out:
# postgresql://fanjum:3cUDV4jctsfF0pYcxoMQ@pg-prod-master.data-191214.com:5432/2x4
# Connection Established!
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File \\VSYS-P-GW01.cloud.vsys.ca\RDFolderRedirect$\fanjum_cwp\Desktop\Python\2x4\venv\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File \\VSYS-P-GW01.cloud.vsys.ca\RDFolderRedirect$\fanjum_cwp\Desktop\Python\2x4\venv\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
# ...

# %%
COT_legacy

# %%
COT_legacy
